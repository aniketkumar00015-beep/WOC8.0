# %% [markdown]
# ## **Polynomial** **Regression**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# %% [markdown]
# **Defining** **Functions**

# %%
def add_polnomail_features(X_train,degree):
  X1=X_train[:,0]
  X2=X_train[:,1]
  X3=X_train[:,2]
  X4=X_train[:,3]
  X5=X_train[:,4]
  X6=X_train[:,5]
  X7=X_train[:,6]
  X=[]
  for i in range(0,degree+1):
    for j in range(0,degree+1):
      for k in range(0,degree+1):
        for l in range(0,degree+1):
          for m in range(0,degree+1):
            for n in range(0,degree+1):
              for o in range(0,degree+1):
                if 0<i+j+k+l+m+n+o<=degree:
                  X.append((X1**i)*(X2**j)*(X3**k)*(X4**l)*(X5**m)*(X6**n)*(X7**o))

  return np.array(X).T

# %%
def compute_cost(X,y,w,b, lambda_):
  m=X.shape[0]
  f_x=w@X.T+b
  f_x=f_x.reshape(m,1)
  cost=np.sum((f_x-y)**2)/(2*m) + (lambda_/(2*m)) * np.sum(w**2)
  return cost

# %%
def compute_gradient(X,y,w,b, lambda_):
  m,n=X.shape
  dj_dw=np.zeros((1,n))
  dj_db=0
  f_x=w@X.T+b
  f_x=f_x.T
  dj_dw=(1/m)*(f_x-y).T@X + (lambda_/m) * w
  dj_db=(1/m)*(np.sum(f_x-y))
  return dj_dw,dj_db

# %%
def gradient_descent(X,y,w_in,b_in,alpha,iteration, lambda_):
  cost_history=[]
  w=w_in
  b=b_in
  for i in range(iteration):
    dj_dw,dj_db=compute_gradient(X,y,w,b, lambda_)
    w=w-alpha*dj_dw
    b=b-alpha*dj_db
    if i<iteration:
      cost_history.append(compute_cost(X,y,w,b, lambda_))
    if i%np.ceil(iteration/10)==0 or i == iteration -1:
      print(f'Iteration {i:4d}: Cost {cost_history[-1]}')
  return w,b,cost_history

# %%
def zscore_normalize_features(X):
  mu=np.mean(X,axis=0)
  std_dev=np.std(X,axis=0)
  X_norm=(X-mu)/std_dev
  return X_norm,mu,std_dev

# %%
def cost_vs_iteration(j):
  iterations=list(range(1,len(j)+1))
  style.use('ggplot')
  plt.plot(iterations,j)
  plt.title('Cost vs Iteration')
  plt.xlabel('Iterations')
  plt.ylabel('Cost')
  plt.show()

# %%
def predict(X,wf,bf):
  pred=wf@X.T+bf
  return pred

# %%
def r2_score(X,y,w,b):
  f_x=w@X.T+b
  # Flatten both arrays to ensure proper shape matching
  f_x = f_x.flatten()
  y = y.flatten()
  y_mean=np.mean(y)
  ss_res=np.sum((f_x-y)**2)
  ss_tot=np.sum((y-y_mean)**2)
  # Avoid division by zero
  if ss_tot == 0:
    return 0.0
  r2=1-(ss_res/ss_tot)
  return r2

# %%
def graphical_analysis(x,y):
  n=x.shape[1]
  style.use('default')
  for i in range(n):
    plt.scatter(x[:,i],y,c='red')
    plt.title(f'Feature {i} and predicted output')
    plt.xlabel(f'Feature {i}')
    plt.ylabel(y)
    plt.show()

# %%
def initialize_parameters(X):
  w=np.zeros((1,X.shape[1]))
  b=0
  return w,b

# %% [markdown]
# **Reading the given data and visualizing it**

# %%
df = pd.read_csv('/content/drive/MyDrive/WOC/poly_train.csv')

df
# Out:
#                 x0            x1          x2          x3             x4  \
# 0     38715.885944  32120.376626 -103.380879 -105.843969  191159.044192
# 1     21988.811712  18001.816613 -260.939557 -236.418680  812765.277732
# 2     42941.208162  38465.966211 -200.070650 -167.055603  528232.118765
# 3     34892.612011  31100.113767  -97.738010 -112.905153  629584.854503
# 4      4781.333207   3734.733691 -270.762509 -250.962600  364154.358662
# ...            ...           ...         ...         ...            ...
# 1195   9679.649897   9484.771066 -205.619892 -202.761704  913783.953043
# 1196  11102.232227  10692.896181  -54.586292  -47.845489  364217.680887
# 1197  32831.208044  27108.107963 -184.661673 -149.622586  861423.545055
# 1198  14511.052395  12052.582508  -64.921970  -54.856176  919177.400297
# 1199  36757.478529  31628.124186   33.904512   34.586060   30833.441653
#
#             x5        x6             y
# 0     1.239707 -0.873959  2.183619e+40
# 1    -1.308924 -0.072857  1.191237e+38
# 2    -0.045137 -0.266585  1.106219e+41
# 3    -0.170694 -0.513813  1.633086e+40
# 4     0.379743 -0.439723  8.481798e+31
# ...        ...       ...           ...
# 1195 -0.191966  0.729017  3.727288e+35
# 1196  1.565789 -0.014281  1.096502e+36
# 1197 -0.418075 -1.827909  4.742902e+39
# 1198  0.178612  0.109499  3.220122e+36
# 1199  0.606593 -1.685147  1.900256e+40
#
# [1200 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# x0    21
# x1    25
# x2    30
# x3    21
# x4    12
# x5    35
# x6    23
# y      0
# dtype: int64

# %% [markdown]
# **Filling Null Value**

# %%
df['x0']=df['x0'].fillna(df['x0'].mean())
df['x1']=df['x1'].fillna(df['x1'].mean())
df['x2']=df['x2'].fillna(df['x2'].mean())
df['x3']=df['x3'].fillna(df['x3'].mean())
df['x4']=df['x4'].fillna(df['x4'].mean())
df['x5']=df['x5'].fillna(df['x5'].mean())
df['x6']=df['x6'].fillna(df['x6'].mean())

# %%
df.isnull().sum()
# Out:
# x0    0
# x1    0
# x2    0
# x3    0
# x4    0
# x5    0
# x6    0
# y     0
# dtype: int64

# %%
df2=df.to_numpy()

X_train=df2[:,0:7]
X_train
# Out:
# array([[ 3.87158859e+04,  3.21203766e+04, -1.03380879e+02, ...,
#          1.91159044e+05,  1.23970691e+00, -8.73958850e-01],
#        [ 2.19888117e+04,  1.80018166e+04, -2.60939557e+02, ...,
#          8.12765278e+05, -1.30892448e+00, -7.28570554e-02],
#        [ 4.29412082e+04,  3.84659662e+04, -2.00070650e+02, ...,
#          5.28232119e+05, -4.51373805e-02, -2.66584885e-01],
#        ...,
#        [ 3.28312080e+04,  2.71081080e+04, -1.84661673e+02, ...,
#          8.61423545e+05, -4.18074629e-01, -1.82790922e+00],
#        [ 1.45110524e+04,  1.20525825e+04, -6.49219704e+01, ...,
#          9.19177400e+05,  1.78611841e-01,  1.09499126e-01],
#        [ 3.67574785e+04,  3.16281242e+04,  3.39045122e+01, ...,
#          3.08334417e+04,  6.06593158e-01, -1.68514662e+00]])

# %%
Y_train=df2[:,7]
Y_mean=np.mean(Y_train)
Y_std=np.std(Y_train)
Y_train_norm=(Y_train-Y_mean)/Y_std
Y_train_norm
# Out:
# array([-0.10096034, -0.47536701,  1.42972305, ..., -0.39565215,
#        -0.47736522, -0.1498127 ])

# %%
X_norm,mean1,std_deviation1=zscore_normalize_features(X_train)

# %%
X_train.max(),X_norm.max()
# Out:
# (np.float64(999522.9290791398), np.float64(4.257627374892887))

# %%
graphical_analysis(X_norm,Y_train_norm)

# %%
X_=add_polnomail_features(X_norm,4)
X_f,mean2,std_deviation2=zscore_normalize_features(X_)

# %%
X_f.shape
# Out:
# (1200, 329)

# %% [markdown]
# **Splitting the data into training and cross validation**

# %%
X_train_data=X_f[:1000,:]
Y_train_data=Y_train_norm[:1000]
Y_train_data=Y_train_data.reshape(1000,1)

X_cv_data=X_f[1000:,:]
Y_cv_data=Y_train_norm[1000:]
Y_cv_data=Y_cv_data.reshape(200,1)

# %%
w,b=initialize_parameters(X_train_data)

# %% [markdown]
# **Running Polynomial Regression**

# %%
alpha=0.001
iteration=6000
lambda_=0.1
wf,bf,j=gradient_descent(X_train_data,Y_train_data,w,b,alpha,iteration, lambda_)
# Out:
# Iteration    0: Cost 0.47309272953002873
# Iteration  600: Cost 0.04035560807903367
# Iteration 1200: Cost 0.02646218149857529
# Iteration 1800: Cost 0.02072611999631158
# Iteration 2400: Cost 0.017605034004364934
# Iteration 3000: Cost 0.015608513566896237
# Iteration 3600: Cost 0.014188119488271825
# Iteration 4200: Cost 0.013103042414218873
# Iteration 4800: Cost 0.012233798700350414
# Iteration 5400: Cost 0.011514819820959182
# Iteration 5999: Cost 0.010907757293732225

# %%
cost_vs_iteration(j)

# %% [markdown]
# **Checking cross validation Set and Training set R2 score**

# %%
r2_train = r2_score(X_train_data, Y_train_data.T, wf, bf)
print(f'R2 Score on Training Data: {r2_train}')
# Out:
# R2 Score on Training Data: 0.9774692944545276

# %%
r2_cv = r2_score(X_cv_data, Y_cv_data.T, wf, bf)
print(f'R2 Score on Cross-Validation Data: {r2_cv}')
# Out:
# R2 Score on Cross-Validation Data: 0.9580899986314837

# %% [markdown]
# **Predicting the output for test data**

# %%
df_tes=pd.read_csv('/content/drive/MyDrive/WOC/poly_test.csv')
df_test=df_tes.to_numpy()
df_tes
# Out:
#                x0            x1          x2          x3             x4  \
# 0     3174.090122   3068.096521   66.048206   88.041572  518895.539006
# 1     6902.381933   5474.606641 -248.355267 -219.375116  661364.700802
# 2    28095.971038  23137.391325 -161.858370 -123.083159  659235.910609
# 3    34210.745198  29225.316687   51.384715   33.648105  894826.786228
# 4     2559.423742   1351.839058   34.768001   36.696550  966655.905518
# ..            ...           ...         ...         ...            ...
# 395  49706.250484  40887.795731 -208.697368 -181.016811  226950.973092
# 396  38620.401109  32576.175143 -276.759568 -260.870019  198413.873128
# 397  20909.191560  17386.627244  -70.719580  -66.361129  338053.622544
# 398  15123.484395  11794.873426  -20.684633  -49.494192  168595.702701
# 399  19439.077578  17144.577728  -57.902868  -51.289535  353482.602946
#
#            x5        x6
# 0   -1.916558  2.330711
# 1    0.795611 -2.102040
# 2    1.064370  0.637355
# 3   -0.658700 -0.696247
# 4    2.629237  1.882180
# ..        ...       ...
# 395  0.990310  1.433784
# 396  0.174052  0.472040
# 397  1.916927 -0.968535
# 398  1.097728  0.508979
# 399 -0.625609 -0.650303
#
# [400 rows x 7 columns]

# %%
X_test=(df_test-mean1)/std_deviation1
X_test
# Out:
# array([[-1.51650099, -1.48289089,  1.62921592, ...,  0.05230823,
#         -1.98087739,  2.31790459],
#        [-1.25765644, -1.28642815, -1.28076847, ...,  0.56273137,
#          0.86644488, -2.02423301],
#        [ 0.21375329,  0.15552673, -0.48019009, ...,  0.55510457,
#          1.14859729,  0.6591637 ],
#        ...,
#        [-0.28520407, -0.3139543 ,  0.36335165, ..., -0.59559267,
#          2.04363882, -0.91389886],
#        [-0.68688902, -0.77045405,  0.82645378, ..., -1.20270821,
#          1.18361723,  0.53341182],
#        [-0.38726984, -0.33371474,  0.48197768, ..., -0.54031538,
#         -0.62559783, -0.60217204]])

# %%
x_1=add_polnomail_features(X_test,4)
x_1.shape
# Out:
# (400, 329)

# %%
x_t=(x_1-mean2)/std_deviation2
x_t.shape
# Out:
# (400, 329)

# %%
wf.shape
# Out:
# (1, 329)

# %%
Y_predicted= x_t@wf.T+bf
Y_predicted.shape
# Out:
# (400, 1)

# %%
Y_predicted=Y_predicted*Y_std+Y_mean

# %%
df_pred=pd.DataFrame(Y_predicted,columns=['Predicted'])
df_pred
# Out:
#         Predicted
# 0   -4.201232e+39
# 1   -4.344690e+39
# 2   -3.512301e+38
# 3    7.904469e+39
# 4    1.716989e+40
# ..            ...
# 395  2.116865e+41
# 396  2.913861e+40
# 397 -1.297633e+39
# 398 -6.533477e+38
# 399  3.543785e+38
#
# [400 rows x 1 columns]

# %%
df_pred.to_csv('Polynomai_Reg_predicted.csv',index=False)
